# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import datetime
sns.set_style('darkgrid')

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='str')

# %%
sns.lineplot(x="total_bill",y="tip",data=df)
plt.title("lineplot")
plt.show()

# %%
sns.scatterplot(x = "total_bill",y="tip",hue="sex",data=df)
plt.title("Scatter Plot")
plt.show()

# %%
sns.barplot(x="day",y="total_bill",data=df)
plt.title("bar plot")
plt.show()

# %%
sns.barplot(x="day",y="total_bill",data=df,ci=None)
plt.title("bar plot")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26396\4249851549.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="day",y="total_bill",data=df,ci=None)

# %%
sns.histplot(df["total_bill"],kde=True)
plt.show()

# %%
sns.boxplot(x="day",y="total_bill",data=df)
plt.show()

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.show()

# %%
x = np.array([1,2,3,4])
y = np.array([10,20,25,30])

plt.plot(x,y)
plt.xticks([1,2,3,4],["mon","tue","wed","thu"])
# plt.xticks()
plt.yticks([0,10,20,30,40])
plt.minorticks_on()
plt.show()

# %%
x = np.linspace(1,10,50)
y = np.exp(x)

print(x)
print(y)
plt.plot(x,y)
plt.yscale("log")
plt.show()
# Out:
# [ 1.          1.18367347  1.36734694  1.55102041  1.73469388  1.91836735
#   2.10204082  2.28571429  2.46938776  2.65306122  2.83673469  3.02040816
#   3.20408163  3.3877551   3.57142857  3.75510204  3.93877551  4.12244898
#   4.30612245  4.48979592  4.67346939  4.85714286  5.04081633  5.2244898
#   5.40816327  5.59183673  5.7755102   5.95918367  6.14285714  6.32653061
#   6.51020408  6.69387755  6.87755102  7.06122449  7.24489796  7.42857143
#   7.6122449   7.79591837  7.97959184  8.16326531  8.34693878  8.53061224
#   8.71428571  8.89795918  9.08163265  9.26530612  9.44897959  9.63265306
#   9.81632653 10.        ]
# [2.71828183e+00 3.26635103e+00 3.92492381e+00 4.71628026e+00
#  5.66719268e+00 6.80983130e+00 8.18285258e+00 9.83270708e+00
#  1.18152108e+01 1.41974337e+01 1.70599685e+01 2.04996572e+01
#  2.46328676e+01 2.95994299e+01 3.55673674e+01 4.27385807e+01
#  5.13556783e+01 6.17101843e+01 7.41524010e+01 8.91032597e+01
#  1.07068561e+02 1.28656088e+02 1.54596164e+02 1.85766368e+02
#  2.23221213e+02 2.68227831e+02 3.22308836e+02 3.87293837e+02
#  4.65381334e+02 5.59213097e+02 6.71963539e+02 8.07447107e+02
#  9.70247332e+02 1.16587189e+03 1.40093894e+03 1.68340100e+03
#  2.02281402e+03 2.43066064e+03 2.92073868e+03 3.50962792e+03
#  4.21725101e+03 5.06754747e+03 6.08928358e+03 7.31702559e+03
#  8.79230911e+03 1.05650443e+04 1.26952044e+04 1.52548545e+04
#  1.83305900e+04 2.20264658e+04]

# %%
dates=[datetime.datetime(2024,1,i) for i in range(1,6)]
values = [10,20,15,25,30]
print(dates)
plt.plot(dates,values)
plt.xticks(dates,rotation=45)
plt.show()
# Out:
# [datetime.datetime(2024, 1, 1, 0, 0), datetime.datetime(2024, 1, 2, 0, 0), datetime.datetime(2024, 1, 3, 0, 0), datetime.datetime(2024, 1, 4, 0, 0), datetime.datetime(2024, 1, 5, 0, 0)]
